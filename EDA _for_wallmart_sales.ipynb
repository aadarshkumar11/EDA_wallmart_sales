# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aadar\\Learnings'

# %%
os.listdir('/Users/aadar/Learnings')
# Out:
# ['.ipynb_checkpoints',
#  'e_com_sales.ipynb',
#  'e_com_sales_data.csv',
#  'gold_monthly_csv.csv',
#  'time_series_forecasting.ipynb',
#  'Untitled.ipynb',
#  'walmart.csv']

# %%
df = pd.read_csv('/Users/aadar/Learnings/walmart.csv')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %%
df['Marital_Status'] = df['Marital_Status'].replace({1 : 'Married', 0 : 'Unmarried'})

# %%
df.describe()
# Out:
#             User_ID     Occupation  Product_Category       Purchase
# count  5.500680e+05  550068.000000     550068.000000  550068.000000
# mean   1.003029e+06       8.076707          5.404270    9263.968713
# std    1.727592e+03       6.522660          3.936211    5023.065394
# min    1.000001e+06       0.000000          1.000000      12.000000
# 25%    1.001516e+06       2.000000          1.000000    5823.000000
# 50%    1.003077e+06       7.000000          5.000000    8047.000000
# 75%    1.004478e+06      14.000000          8.000000   12054.000000
# max    1.006040e+06      20.000000         20.000000   23961.000000

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category',
#        'Purchase'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'Gender', data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#sales_q = df_new.groupby(['Country'], as_index=False) ['Quantity'].sum().sort_values(by = 'Quantity', ascending = False)

# %%
sales_gender = df.groupby(['Gender'], as_index = False) ['Purchase'].sum().sort_values(by = 'Purchase', ascending = False)

# %%
sales_gender
# Out:
#   Gender    Purchase
# 1      M  3909580100
# 0      F  1186232642

# %%
ay = sns.barplot(x = 'Gender', y = 'Purchase', data = sales_gender)

# %%
plot1 = sns.barplot(x = 'Age', y = 'Purchase', data = df, hue = 'Gender')

# for bars in plot1.containers:
#     plot1.bar_label(bars)

# %%
sales_age = df.groupby(['Age'], as_index = False)['Purchase'].sum().sort_values(by = 'Age', ascending = True)

plot2 = sns.barplot(x = 'Age', y = 'Purchase', data = sales_age)

# for bars in plot2.containers:
#     plot2.bar_label(bars)

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category',
#        'Purchase'],
#       dtype='object')

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category  Purchase
# 0                          2      Unmarried                 3      8370
# 1                          2      Unmarried                 1     15200
# 2                          2      Unmarried                12      1422
# 3                          2      Unmarried                12      1057
# 4                         4+      Unmarried                 8      7969

# %%
sns.countplot(x = 'City_Category', data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
sales_city = df.groupby(['City_Category', 'Gender'], as_index = False)['Purchase'].sum().sort_values(by = 'Purchase', ascending = False)
plot3 = sns.barplot(x = 'City_Category', y = 'Purchase', hue = 'Gender', data = sales_city)

# %%
sns.countplot(x = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sales_ms = df.groupby(['Marital_Status', 'Gender'], as_index = False) ['Purchase'].sum().sort_values(by = 'Purchase', ascending = True)

sns.barplot(x = 'Marital_Status', y = 'Purchase', hue = 'Gender', data = sales_ms)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='Purchase'>

# %%
sns.set(rc = {'figure.figsize':(15,8)})
plot4 = sns.countplot(x = 'Occupation', data = df)

for bars in plot4.containers:
    plot4.bar_label(bars)

# %%
sales_occ = df.groupby(['Occupation'], as_index = False) ['Purchase'].sum().sort_values(by = 'Purchase', ascending =True)
sns.set(rc = {'figure.figsize':(15,5)})
sns.barplot(x = 'Occupation', y = 'Purchase', data = sales_occ)
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years Marital_Status  Product_Category  Purchase
# 0                          2      Unmarried                 3      8370
# 1                          2      Unmarried                 1     15200
# 2                          2      Unmarried                12      1422
# 3                          2      Unmarried                12      1057
# 4                         4+      Unmarried                 8      7969

# %%
sns.set(rc = {'figure.figsize':(15,5)})

plot5 = sns.countplot(x = 'Product_Category', data = df)

for bars in plot5.containers:
    plot5.bar_label(bars)

# %%
sales_product = df.groupby(['Product_Category'], as_index = False) ['Purchase'].sum().sort_values(by = 'Purchase', ascending = False)

sns.barplot(x = 'Product_Category', y = 'Purchase', data = sales_product)
# Out:
# <Axes: xlabel='Product_Category', ylabel='Purchase'>
